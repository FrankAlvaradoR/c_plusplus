# %% [markdown]
# <a href="https://colab.research.google.com/github/FrankAlvaradoR/c_plusplus/blob/main/clase3_programaci_n_avanzada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile main.cpp
# #include <fstream>
# /*Maneja la lectura y escritura de archivos físicos en el disco duro.
# Contiene las clases necesarias para manipular documentos,
# como std::ifstream (flujo de entrada para leer archivos)
#  y std::ofstream (flujo de salida para escribir en ellos).*/
# int main(){
#   std::ofstream archivo;
#   archivo.open("miarchivo.txt");
#   archivo<<"hola desde este archivo\n";
#   archivo<<"ya he escrito algo\n";
#   archivo.close();
# }
# Out:
# Overwriting main.cpp

# %%
#Ejecuatamos es Script
# %%script bash
g++ main.cpp
./a.out

# %%
# %%writefile main.cpp
# #include <fstream>
# /*Maneja la lectura y escritura de archivos físicos en el disco duro.
# Contiene las clases necesarias para manipular documentos,
# como std::ifstream (flujo de entrada para leer archivos)
#  y std::ofstream (flujo de salida para escribir en ellos).*/
#
# int main(){
#   std::ofstream archivo("miarchivo2.txt");
#   archivo<<"hola desde este archivo\n";
#   archivo<<"ya he escrito algo\n";
#   archivo.close();
# }
# Out:
# Overwriting main.cpp

# %%
#Ejecuatamos es Script
# %%script bash
g++ main.cpp
./a.out

# %%
# %%writefile main.cpp
# #include<iostream>
# /* Maneja la interacción con la consola.
# Proporciona herramientas como std::cout para imprimir texto en la pantalla y
# std::cin para capturar la información que el usuario teclea. */
# #include<fstream>
# /*Maneja la lectura y escritura de archivos físicos en el disco duro.
# Contiene las clases necesarias para manipular documentos,
# como std::ifstream (flujo de entrada para leer archivos)
#  y std::ofstream (flujo de salida para escribir en ellos).*/
#
# int main(){
#   std::ofstream archivo("miarchivo2.txt", std::ios::app);
#   archivo<<"hola desde este archivo de nuevo\n";
#   archivo<<"ya he escrito algo de nuevo\n";
#   archivo.close();
# }
# Out:
# Overwriting main.cpp

# %%
#Ejecuatamos es Script
# %%script bash
g++ main.cpp
./a.out

# %%
# %%writefile main.cpp
# #include<iostream>
# #include<fstream>
# int main(){
#   char caracter;
#   std::ifstream archivo("miarchivo2.txt", std::ios::in);
#   while(!archivo.eof()){
#   archivo.get(caracter);
#   std::cout<<caracter;
#   }
# archivo.close();
# }
# Out:
# Overwriting main.cpp

# %%
#Ejecuatamos es Script
# %%script bash
g++ main.cpp
./a.out
# Out:
# hola desde este archivo
# ya he escrito algo
# hola desde este archivo de nuevo
# ya he escrito algo de nuevo

# %%
# %%writefile main.cpp
# #include <fstream>
# int main(){
#   std::ofstream archivo;
#   archivo.open("arch.txt");
#   archivo<<"hola\n";
#   archivo<<"como estas?\n";
#   archivo<<"bien\n";
#   archivo<<"que haces?\n";
#   archivo<<"nada\n";
#   archivo<<"pues ponte a hacer algo, a que te dedicas?\n";
#   archivo<<"estudio\n";
#   archivo<<"y que estudias?\n";
#   archivo<<"Biomédica\n";
#   archivo<<"ha que bueno!!, de donde eres?\n";
#   archivo<<"de guadalajara\n";
#   archivo<<"que interesante, hay algo que quieras preguntarme?\n";
#   archivo<<"como te llamas?\n";
#   archivo<<"acaso eso importa?\n";
#   archivo<<"como te llamas\n";
#   archivo<<"pregunta de nuevo\n";
#   archivo<<" \n";
#   archivo.close();
# }
# Out:
# Overwriting main.cpp

# %%
#Ejecuatamos es Script
# %%script bash
g++ main.cpp
./a.out

# %%
# %%writefile main.cpp
# #include<iostream>
# #include<fstream>
# #include<string.h>
# /*La biblioteca <string.h> proporciona funciones estándar diseñadas
# para manipular cadenas de caracteres al estilo C
# (arreglos de tipo char terminados en nulo \0) y
# para realizar operaciones directas sobre bloques de memoria. */
#
# int main(){
#   char texto_preg[300],texto_resp[300],*compara=NULL;
#   std::ifstream archivo("arch.txt", std::ios::in);
#   if(!archivo){
#     std::cerr<<"error al abrir el archivo";
#     return 1;
#   }
#   std::cout<<"* hola"<<"\n";
#   std::cout<<"> ";
#   std::cin.getline(texto_resp,290);
#   while(texto_resp[0]!='\0'){
#     archivo.seekg(0);
#     do{
#       archivo.getline(texto_preg,290);
#       compara=strstr(texto_resp,texto_preg);
#       if(archivo.eof()){
#         std::cout<<"* no se contestar, dimelo por favor"<<"\n";
#         std::cin.getline(texto_preg,290);
#         archivo.close();
#         std::ofstream archivoS("arch.txt",std::ios::app);
#         archivoS<<texto_resp<<"\n";
#         archivoS<<texto_preg<<"\n";
#         archivoS.close();
#         archivo.open("arch.txt", std::ios::in);
#       }
#     }while(compara==NULL);
#       std::cout<<"> ";
#       archivo.getline(texto_preg,290);
#       std::cout<<"* "<<texto_preg<<"\n";
#       std::cout<<"> ";
#       std::cin.getline(texto_resp,290);
#     }
#   archivo.close();
#   return 0;
# }
# Out:
# Overwriting main.cpp

# %%
#Ejecuatamos es Script
# %%script bash
g++ main.cpp
./a.out
# Out:
# * hola
# >

# %%
# %%writefile main.cpp
# #include <iostream>
#
# using namespace std;
# const double EUR_PTS = 166;
# int main()
# {
#     cout<<"Introduce la cantidad (en euros):";
#     double euros;
#     cin>> euros;
#     double pesetas = euros * EUR_PTS;
#     cout << euros << "Euros equivalen a " << pesetas << "Pts" <<endl;
#
#     return 0;
# }
# Out:
# Overwriting main.cpp

# %%
#Ejecuatamos es Script
# %%script bash
g++ main.cpp
./a.out
# Out:
# Introduce la cantidad (en euros):6.6803e-310Euros equivalen a 1.10893e-307Pts

# %%
# %%writefile main.cpp
# #include <iostream>
# #include <iomanip>
# using namespace std ;
# int main()
# {bool x = true ;
# cout << boolalpha << x << endl; // escribe los booleanos como ’false’ o ’true’
# cout << dec << 27 << endl; // escribe 27 (decimal)
# cout << hex << 27 << endl; // escribe 1b (hexadecimal)
# cout << oct << 27 << endl; // escribe 33 (octal)
# cout << setprecision(2) << 4.567 <<'\n'; // escribe 4.6
# cout << setw(5) << dec << 234 << endl; // escribe " 234"
# cout << setfill('#') << setw(5) << 234 << endl; // escribe "##234"
# }
# Out:
# Overwriting main.cpp

# %%
#Ejecuatamos es Script
# %%script bash
g++ main.cpp
./a.out
# Out:
# true
# 27
# 1b
# 33
# 4.6
#   234
# ##234
