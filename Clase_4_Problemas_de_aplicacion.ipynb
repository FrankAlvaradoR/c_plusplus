# %% [markdown]
# <a href="https://colab.research.google.com/github/FrankAlvaradoR/c_plusplus/blob/main/Clase_4_Problemas_de_aplicacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Analizar Texto
# %%writefile main.cpp
#include <iostream>
#include <fstream>
using namespace std;
int main(){
  char caracter;
  ifstream archivo("Copia de EjemploTexto.txt",ios::in);
  while(!archivo.eof()){
    archivo.get(caracter);
    cout<<caracter;
  }
archivo.close();
}
# Out:
# Overwriting main.cpp

# %%
#Ejecuatamos es Script
# %%script bash
g++ main.cpp 
./a.out
# Out:
# The Project Gutenberg eBook of Recollections and impressions of James
# A. McNeill Whistler, by Arthur Jerome Eddy
#
# This eBook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this eBook or online at
# www.gutenberg.org. If you are not located in the United States, you
# will have to check the laws of the country where you are located before
# using this eBook.
#
# Title: Recollections and impressions of James A. McNeill Whistler
#
# Author: Arthur Jerome Eddy
#
# Release Date: July 2, 2022 [eBook #68447]
#
# Language: English
#
# Produced by: Chuck Greif and the Online Distributed Proofreading Team at
#              http://www.pgdp.net (This file was produced from images
#              available at The Internet Archive)
#
# ...

# %%
#Analizar Texto
# %%writefile main.cpp
#include <iostream>
#include <fstream>
using namespace std;
int main(){
  char caracter;
  int cuenta_a=0;
  int cuenta_e=0;
  int cuenta_i=0;
  int cuenta_o=0;
  int cuenta_u=0;
  ifstream archivo("Copia de EjemploTexto.txt",ios::in);
  while(!archivo.eof()){
    archivo.get(caracter);
    if ((caracter=='a') | (caracter=='A')) 
      cuenta_a++;
    if ((caracter=='e') | (caracter=='E')) 
      cuenta_e++;
    if ((caracter=='i') | (caracter=='I')) 
      cuenta_i++; 
    if ((caracter=='o') | (caracter=='O')) 
      cuenta_o++; 
    if ((caracter=='u') | (caracter=='U')) 
      cuenta_u++;      
    cout<<caracter;
  }
archivo.close();
printf("\n \nLa a aparece : %d veces \n",cuenta_a);
printf("La e aparece : %d veces \n",cuenta_e);
printf("La i aparece : %d veces \n",cuenta_i);
printf("La o aparece : %d veces \n",cuenta_o);
printf("La u aparece : %d veces \n",cuenta_u);
}
# Out:
# Overwriting main.cpp

# %%
#Ejecuatamos es Script
# %%script bash
g++ main.cpp 
./a.out

# %%
#Analizar Texto
# %%writefile main.cpp
#include <iostream>
#include <cstring>
#include <sstream>
using namespace std;

int convertir(char a){
  int resultado; 
  resultado = a - 48;
  return resultado;}

int suma(int a, int b){
  int resultado;
  resultado = a + b;
  return resultado;}

int resta(int a, int b){
  int resultado;
  resultado = a - b;
  return resultado;}

int multi(int a, int b){
  int resultado;
  resultado = a * b;
  return resultado;} 

int divi(int a, int b){
  int resultado;
  resultado = a / b;
  return resultado;} 

int main(){
  string str1 = "1+2+3+4-3-2-1";

  int longitud, resultado = 0;
  longitud=str1.length();

  for (int i=0;i<longitud;i++)
    { 
      if (resultado == 0){
        if (str1[i] == '+') {resultado = suma(convertir(str1[i-1]),convertir(str1[i+1]));  i++;}
        if (str1[i] == '-') {resultado = resta(convertir(str1[i-1]),convertir(str1[i+1]));   i++;}
        if ((str1[i] == '*') | (str1[i] == 'x')) {resultado = multi(convertir(str1[i-1]),convertir(str1[i+1]));  i++;}
        if (str1[i] == '/') {resultado = divi(convertir(str1[i-1]),convertir(str1[i+1]));  i++;}}
      else{ 
        if (str1[i] == '+') {resultado = suma(resultado,convertir(str1[i+1]));  i++;}
        if (str1[i] == '-') {resultado = resta(resultado,convertir(str1[i+1]));   i++;}
        if ((str1[i] == '*') | (str1[i] == 'x')) {resultado = multi(resultado,convertir(str1[i+1]));  i++;}
        if (str1[i] == '/') {resultado = divi(resultado,convertir(str1[i+1]));  i++;}} 
    }
  printf ("El resultado es: %d ",resultado);
}
# Out:
# Overwriting main.cpp

# %%
#Ejecuatamos es Script
# %%script bash
g++ main.cpp 
./a.out
# Out:
# El resultado es: 4

# %%
#Analizar Texto
# %%writefile main.cpp
#include <iostream>
#include <cstring>

using namespace std;

int convertir(char a){
  int resultado; 
  resultado = a - 48;
  return resultado;}

int suma(int a, int b){
  int resultado;
  resultado = a + b;
  return resultado;}

int resta(int a, int b){
  int resultado;
  resultado = a - b;
  return resultado;}

int multi(int a, int b){
  int resultado;
  resultado = a * b;
  return resultado;} 

int divi(int a, int b){
  int resultado;
  resultado = a / b;
  return resultado;} 

int numero(string strx, int i, int con){
  int x,con1=0;
  for (int c=(i-con);c<con;c++){
    if (con1==0) x=convertir(strx[c]); 
    if (con1>0) x=(multi(x,10)+convertir(strx[c])); 
    con1++;}
  return x;
}

int main(){
  string str1 = "34*2";

  int longitud, resultado = 0, con=0, num1=0, num2;
  longitud=str1.length();

  for (int i=0;i<longitud;i++)
    { 
      if (num1==0){ 
        if ((str1[i]<48)|(str1[i]>57))
         {num1=numero(str1,i,con);
          con=0;}
        else
          {con++;
          continue;}}
            
      if (resultado == 0){
        if (str1[i] == '+') {resultado = suma(num1,convertir(str1[i+1]));  i++;}
        if (str1[i] == '-') {resultado = resta(num1,convertir(str1[i+1]));   i++;}
        if ((str1[i] == '*') | (str1[i] == 'x')) {resultado = multi(num1,convertir(str1[i+1]));  i++;}
        if (str1[i] == '/') {resultado = divi(num1,convertir(str1[i+1]));  i++;}}
      else{ 
        if (str1[i] == '+') {resultado = suma(resultado,convertir(str1[i+1]));  i++;}
        if (str1[i] == '-') {resultado = resta(resultado,convertir(str1[i+1]));   i++;}
        if ((str1[i] == '*') | (str1[i] == 'x')) {resultado = multi(resultado,convertir(str1[i+1]));  i++;}
        if (str1[i] == '/') {resultado = divi(resultado,convertir(str1[i+1]));  i++;}} 
    }
  printf ("El resultado es: %d ",resultado);
}
# Out:
# Overwriting main.cpp

# %%
#Ejecuatamos es Script
# %%script bash
g++ main.cpp 
./a.out
# Out:
# Cantidad de operadores en la expresión: 3
# El resultado es: 272
# main.cpp: In function ‘int busca_operacion(std::__cxx11::string, int)’:
# main.cpp:55:10: error: invalid conversion from ‘int*’ to ‘int’ [-fpermissive]
#    return operador;
#           ^~~~~~~~
# main.cpp:50:17: warning: address of local variable ‘operador’ returned [-Wreturn-local-addr]
#    int ban1 = 0, operador[20];
#                  ^~~~~~~~
# main.cpp: In function ‘int main()’:
# main.cpp:66:43: error: incompatible types in assignment of ‘int’ to ‘int [20]’
#    operador = busca_operacion(str1,longitud);
#                                            ^

# %%
#Analizar Texto
# %%writefile main.cpp
#include <iostream>
#include <cstring>

using namespace std;

int convertir(char a){
  int resultado; 
  resultado = a - 48;
  return resultado;}

int suma(int a, int b){
  int resultado;
  resultado = a + b;
  return resultado;}

int resta(int a, int b){
  int resultado;
  resultado = a - b;
  return resultado;}

int multi(int a, int b){
  int resultado;
  resultado = a * b;
  return resultado;} 

int divi(int a, int b){
  int resultado;
  resultado = a / b;
  return resultado;} 

int numero(string strx, int i, int con){
  int x,con1=0;
  for (int c=(i-con);c<con;c++){
    if (con1==0) x=convertir(strx[c]); 
    if (con1>0) x=(multi(x,10)+convertir(strx[c])); 
    con1++;}
  return x;
}

int cantidad_operacion(string str1, int longitud){
  int ban1 = 0, operador[20];
  for (int i=0;i<longitud;i++){
        if ((str1[i]<48)|(str1[i]>57))
        {  operador[ban1]=i;
           ban1++;}}
  return ban1;          
}

int busca_operacion(string str1, int longitud){
  int ban1 = 0, ban2=0;
  for (int i=0;i<longitud;i++){
        if ((str1[i]<48)|(str1[i]>57))
           ban1++;
  for (int i=0;i<longitud;i++){
        if ((str1[i]<48)|(str1[i]>57))
           ban1++;
  
  return operador;          
}

int main(){
  string str1 = "34*2*4*1";

  int longitud, resultado = 0, con=0, num1=0, num2;
  int operaciones, operador[20];
  longitud=str1.length();
  operaciones= cantidad_operacion(str1, longitud);
  printf("\nCantidad de operadores en la expresión: %d\n",operaciones);

  operador = busca_operacion(str1,longitud);
  for (int i=0;i<longitud;i++)
    { 
      if (num1==0){ 
        if ((str1[i]<48)|(str1[i]>57))
         {num1=numero(str1,i,con);
          con=0;}
        else
          {con++;
          continue;}}
            
      if (resultado == 0){
        if (str1[i] == '+') {resultado = suma(num1,convertir(str1[i+1]));  i++;}
        if (str1[i] == '-') {resultado = resta(num1,convertir(str1[i+1]));   i++;}
        if ((str1[i] == '*') | (str1[i] == 'x')) {resultado = multi(num1,convertir(str1[i+1]));  i++;}
        if (str1[i] == '/') {resultado = divi(num1,convertir(str1[i+1]));  i++;}}
      else{ 
        if (str1[i] == '+') {resultado = suma(resultado,convertir(str1[i+1]));  i++;}
        if (str1[i] == '-') {resultado = resta(resultado,convertir(str1[i+1]));   i++;}
        if ((str1[i] == '*') | (str1[i] == 'x')) {resultado = multi(resultado,convertir(str1[i+1]));  i++;}
        if (str1[i] == '/') {resultado = divi(resultado,convertir(str1[i+1]));  i++;}} 
    }
  printf ("El resultado es: %d ",resultado);
}
# Out:
# Overwriting main.cpp

# %%
#Ejecuatamos es Script
# %%script bash
g++ main.cpp 
./a.out
# Out:
# Cantidad de operadores en la expresión: 3
# El resultado es: 272
# main.cpp: In function ‘int busca_operacion(std::__cxx11::string, int)’:
# main.cpp:55:10: error: invalid conversion from ‘int*’ to ‘int’ [-fpermissive]
#    return operador;
#           ^~~~~~~~
# main.cpp:50:17: warning: address of local variable ‘operador’ returned [-Wreturn-local-addr]
#    int ban1 = 0, operador[20]={0};
#                  ^~~~~~~~
# main.cpp: In function ‘int main()’:
# main.cpp:67:43: error: incompatible types in assignment of ‘int’ to ‘int [20]’
#    operador = busca_operacion(str1,longitud);
#                                            ^
